# %%
import pandas as pd
import numpy as np

# %%
#Q1.Write a Pandas program to detect missing values of a given DataFrame. Display True or False

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})


def missing_values():
    
    for column in df.columns:
        null_count= df[column].isnull().sum()
        total_values=df.shape[0]
        
        percentage= null_count / total_values * 100
        
        print(column,":",round(percentage,2),'%')

print("Null Percentage for Each Column:")
print("****************")
missing_values()
# Out:
# Null Percentage for Each Column:
# ****************
# ord_no : 33.33 %
# purch_amt : 0.0 %
# ord_date : 8.33 %
# customer_id : 0.0 %
# salesman_id : 25.0 %

# %%
#Q2.Write a Pandas program to identify the column(s) of a given DataFrame which have at least one missing value.

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

columns=[col for col in df.columns if df[col].isna().sum()>=1 ]  # or we can use df.isna().any()
print('Columns with atleast one Null value::')
columns
# Out:
# Columns with atleast one Null value::
# ['ord_no', 'ord_date', 'salesman_id']

# %%
#Q3.Write a Pandas program to count the number of missing values in each column of a given DataFrame.

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df.isnull().sum()
# Out:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
#Q4.Write  Pandas program to find and replace the missing values in a given DataFrame which do not have any valuable information

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df.fillna(0) # or df.replace({"?": np.nan, "--": np.nan}) it replaces "?" and "--" with Nan value
# Out:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       0.0     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26           0         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          0.0
# 4       0.0     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       0.0    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          0.0
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      0.0      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          0.0

# %%
#Q5.Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df.dropna()
# Out:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0  70001.0     150.50  2012-10-05         3002       5002.0
# 5  70005.0    2400.60  2012-07-27         3001       5001.0
# 8  70003.0    2480.40  2012-10-10         3003       5003.0
# 9  70012.0     250.45  2012-06-27         3002       5002.0

# %%
#Q5.Write a Pandas program to drop the columns where at least one element is missing in a given DataFrame

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df.dropna(axis=1)
# Out:
#     purch_amt  customer_id
# 0      150.50         3002
# 1      270.65         3001
# 2       65.26         3001
# 3      110.50         3003
# 4      948.50         3002
# 5     2400.60         3001
# 6     5760.00         3001
# 7     1983.43         3004
# 8     2480.40         3003
# 9      250.45         3002
# 10      75.29         3001
# 11    3045.60         3001

# %%
#Q7. Write a Pandas program to drop the rows where all elements are missing in a given DataFrame.
df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[np.nan,270.65,65.26,110.5,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,3045.6],
'ord_date': [np.nan,'2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[np.nan,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001]})


df.dropna(how='all') # by specifying "all" we are telling the func to delete  rows where all values are NaN
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 3   70004.0     110.50  2012-08-17       3003.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0
# 11  70013.0    3045.60  2012-04-25       3001.0

# %%
#Q8.Write a Pandas program to keep the rows with at least 2 NaN values in a given DataFrame.

df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})

df.dropna(thresh=2) # Default axis=0 ; Require that many non-NA values.
# Out:
#      ord_no  purch_amt    ord_date  customer_id
# 1       NaN     270.65  2012-09-10       3001.0
# 2   70002.0      65.26         NaN       3001.0
# 4       NaN     948.50  2012-09-10       3002.0
# 5   70005.0    2400.60  2012-07-27       3001.0
# 6       NaN    5760.00  2012-09-10       3001.0
# 7   70010.0    1983.43  2012-10-10       3004.0
# 8   70003.0    2480.40  2012-10-10       3003.0
# 9   70012.0     250.45  2012-06-27       3002.0
# 10      NaN      75.29  2012-08-17       3001.0

# %%
#Q9.Write a Pandas program to drop those rows from a given DataFrame in which specific columns have missing values

df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})

df.dropna(subset=['ord_no','ord_date']) # it delete all those rows where these two columns have any null value
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %%
#Q10.Write a Pandas program to keep the valid entries of a given DataFrame.

df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})

df=df.dropna()
df
# Out:
#     ord_no  purch_amt    ord_date  customer_id
# 5  70005.0    2400.60  2012-07-27       3001.0
# 7  70010.0    1983.43  2012-10-10       3004.0
# 8  70003.0    2480.40  2012-10-10       3003.0
# 9  70012.0     250.45  2012-06-27       3002.0

# %%
#Q11.Write a Pandas program to calculate the total number of missing values in a DataFrame


df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})

print('Total Missing Values : ',(df.isnull().sum()).sum())
# Out:
# Total Missing Values :  17

# %%
#Q12.Write a Pandas program to replace NaNs with a single constant value in specified columns in a DataFrame.

df = pd.DataFrame({
'ord_no':[np.nan,np.nan,70002,np.nan,np.nan,70005,np.nan,70010,70003,70012,np.nan,np.nan],
'purch_amt':[np.nan,270.65,65.26,np.nan,948.5,2400.6,5760,1983.43,2480.4,250.45, 75.29,np.nan],
'ord_date': [np.nan,'2012-09-10',np.nan,np.nan,'2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17',np.nan],
'customer_id':[np.nan,3001,3001,np.nan,3002,3001,3001,3004,3003,3002,3001,np.nan]})

df['ord_no'].fillna(123)  # fills all null values in column with 123
# Out:
# 0       123.0
# 1       123.0
# 2     70002.0
# 3       123.0
# 4       123.0
# 5     70005.0
# 6       123.0
# 7     70010.0
# 8     70003.0
# 9     70012.0
# 10      123.0
# 11      123.0
# Name: ord_no, dtype: float64

# %%
#Q13.Write a Pandas program to replace NaNs with the value from the previous row or the next row in a given DataFrame

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN        NaN     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0        NaN       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0        NaN       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %%
print("\nReplacing NaNs with the value from the previous row (purch_amt):")
df['purch_amt'].fillna(method='pad', inplace=True)
print(df)
print("\nReplacing NaNs with the value from the next row (sale_amt):")
df['sale_amt'].fillna(method='bfill', inplace=True)
print(df)
# Out:
# Replacing NaNs with the value from the previous row (purch_amt):
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN     150.50     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26       NaN         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0     948.50       NaN  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0    1983.43       NaN  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# ...

# %%
#Q14.Write a Pandas program to replace NaNs with median or mean of the specified columns in a given DataFrame

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df['purch_amt'].fillna(df['purch_amt'].median(), inplace=True)

df['sale_amt'].fillna(int(df['sale_amt'].mean()), inplace=True)
df
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1       NaN     250.45     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     39.00         NaN         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003          NaN
# 4       NaN     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0     250.45     39.00  2012-07-27         3001       5001.0
# 6       NaN    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004          NaN
# 8   70003.0     250.45     39.00  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10      NaN      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001          NaN

# %%
#Q17. Write a Pandas program to count the missing values in a given DataFrame.

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df['purch_amt'].isna().sum()
# Out:
# 3

# %%
#Q18. Write a Pandas program to find the Indexes of missing values in a given DataFrame

df['ord_no'].isnull().to_numpy().nonzero()
# Out:
# (array([ 1,  4,  6, 10], dtype=int64),)

# %%
#Q19.WritePandas program to replace the missing values with the most frequent values present in each column of a given DataFrame

df = pd.DataFrame({
'ord_no':[70001,np.nan,70002,70004,np.nan,70005,np.nan,70010,70003,70012,np.nan,70013],
'purch_amt':[150.5,np.nan,65.26,110.5,948.5,np.nan,5760,1983.43,np.nan,250.45, 75.29,3045.6],
'sale_amt':[10.5,20.65,np.nan,11.5,98.5,np.nan,57,19.43,np.nan,25.45, 75.29,35.6],
'ord_date': ['2012-10-05','2012-09-10',np.nan,'2012-08-17','2012-09-10','2012-07-27','2012-09-10','2012-10-10','2012-10-10','2012-06-27','2012-08-17','2012-04-25'],
'customer_id':[3002,3001,3001,3003,3002,3001,3001,3004,3003,3002,3001,3001],
'salesman_id':[5002,5003,5001,np.nan,5002,5001,5001,np.nan,5003,5002,5003,np.nan]})

df.fillna(df.mode().iloc[0])
# Out:
#      ord_no  purch_amt  sale_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50     10.50  2012-10-05         3002       5002.0
# 1   70001.0      65.26     20.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26     10.50  2012-09-10         3001       5001.0
# 3   70004.0     110.50     11.50  2012-08-17         3003       5001.0
# 4   70001.0     948.50     98.50  2012-09-10         3002       5002.0
# 5   70005.0      65.26     10.50  2012-07-27         3001       5001.0
# 6   70001.0    5760.00     57.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43     19.43  2012-10-10         3004       5001.0
# 8   70003.0      65.26     10.50  2012-10-10         3003       5003.0
# 9   70012.0     250.45     25.45  2012-06-27         3002       5002.0
# 10  70001.0      75.29     75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60     35.60  2012-04-25         3001       5001.0
