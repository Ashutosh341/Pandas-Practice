# %%
import pandas as pd
import numpy as np

# %%
#Q1. Write a Pandas program to import excel data (coalpublic2013.xlsx ) into a Pandas dataframe

df=pd.read_excel("C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\coalpublic2013.xls",header=3)

df.head(3)
# Out:
#    Year  MSHA ID                       Mine Name Mine State Mine County  \
# 0  2013   103381            Tacoa Highwall Miner    Alabama        Bibb
# 1  2013   103404                Reid School Mine    Alabama      Blount
# 2  2013   100759  North River #1 Underground Min    Alabama     Fayette
#
#                           Mine Status    Mine Type  \
# 0  Active, men working, not producing      Surface
# 1               Permanently abandoned      Surface
# 2  Active, men working, not producing  Underground
#
#                    Company Type              Operation Type  \
# 0  Indepedent Producer Operator                   Mine only
# 1  Indepedent Producer Operator                   Mine only
# 2  Indepedent Producer Operator  Mine and Preparation Plant
#
#                Operating Company  \
# 0        Jesse Creek Mining, Llc
# 1  Taft Coal Sales & Associates,
# 2       Jim Walter Resources Inc
#
#                            Operating Company Address Union Code  \
# ...

# %%
#Q2. Write a Pandas program to get the data types of the given excel data (coalpublic2013.xlsx ) fields

df.dtypes
# Out:
# Year                          int64
# MSHA ID                       int64
# Mine Name                    object
# Mine State                   object
# Mine County                  object
# Mine Status                  object
# Mine Type                    object
# Company Type                 object
# Operation Type               object
# Operating Company            object
# Operating Company Address    object
# Union Code                   object
# Coal Supply Region           object
# Production (short tons)       int64
# Average Employees             int64
# Labor Hours                   int64
# dtype: object

# %%
#Q3. Write a Pandas program to read specific columns from a given excel file

df.iloc[:,5:9]
# Out:
#                              Mine Status    Mine Type  \
# 0     Active, men working, not producing      Surface
# 1                  Permanently abandoned      Surface
# 2     Active, men working, not producing  Underground
# 3                                 Active      Surface
# 4                                 Active      Surface
# ...                                  ...          ...
# 1445  Active, men working, not producing       Refuse
# 1446  Active, men working, not producing       Refuse
# 1447                              Active       Refuse
# 1448                              Active       Refuse
# 1449  Active, men working, not producing       Refuse
#
#                       Company Type              Operation Type
# 0     Indepedent Producer Operator                   Mine only
# 1     Indepedent Producer Operator                   Mine only
# 2     Indepedent Producer Operator  Mine and Preparation Plant
# ...

# %%
#Q4.Write Pandas program to find the sum, mean, max, min value of 'Production (short tons)' column of coalpublic2013.xlsx file

print("Sum: ",df["Production (short tons)"].sum()) 
print("Mean: ",df["Production (short tons)"].mean())
print("Maximum: ",df["Production (short tons)"].max())
print("Minimum: ",df["Production (short tons)"].min())
# Out:
# Sum:  984841779
# Mean:  679201.2268965517
# Maximum:  111005549
# Minimum:  0

# %%
#Q5.Write a Pandas program to insert a column in the sixth position of the said excel sheet and fill it with NaN values

df.insert(6,'col6',np.nan)
df
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1445  2013  1103254                   Fidelity Mine  Refuse Recovery
# 1446  2013  1102636                             Wfi  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
# 1448  2013  1518524               Turkey Pen Refuse  Refuse Recovery
# 1449  2013  1519685           Fedscreek Refuse Pile  Refuse Recovery
#
#      Mine County                         Mine Status  col6    Mine Type  \
# ...

# %%
#Q6.Write a Pandas program to import some excel data (coalpublic2013.xlsx ) skipping first twenty rows into a Pandas dataframe

df=pd.read_excel("C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\coalpublic2013.xls",
                 skiprows=20)

# %%
#Q9.Write Pandas program to create a subtotal of "Labor Hours" against MSHA ID from the given excel data 

df=pd.read_excel("C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\coalpublic2013.xls",
                 header=3)

df.groupby('MSHA ID')['Labor Hours'].sum().reset_index(name='Labor Hours')
# Out:
#       MSHA ID  Labor Hours
# 0      100329       144002
# 1      100347       215295
# 2      100515         6240
# 3      100759       474784
# 4      100851      1001809
# ...       ...          ...
# 1316  4801353      2811138
# 1317  4801429       161270
# 1318  4801645        35687
# 1319  4801646       661265
# 1320  5000030       286079
#
# [1321 rows x 2 columns]

# %%
#Q10. Write a Pandas program to import excel data (coalpublic2013.xlsx ) into a dataframe and find a specific MSHA ID

df.loc[df['MSHA ID']==100329]
# Out:
#    Year  MSHA ID     Mine Name Mine State Mine County Mine Status  \
# 6  2013   100329  Concord Mine    Alabama   Jefferson      Active
#
#      Mine Type          Company Type     Operation Type  \
# 6  Underground  Operating Subsidiary  Preparation Plant
#
#          Operating Company                  Operating Company Address  \
# 6  Oak Grove Resources Llc  8360 Taylors Ferry Rd, Hueytown, AL 35023
#
#   Union Code   Coal Supply Region  Production (short tons)  Average Employees  \
# 6       UNIT  Appalachia Southern                        0                 59
#
#    Labor Hours
# 6       144002

# %%
#Q11.Write Pandas program to import excel data  into a dataframe and find details where "Labor Hours" > 20000.

df.loc[df['Labor Hours']>20000]
# Out:
#       Year  MSHA ID                       Mine Name       Mine State  \
# 0     2013   103381            Tacoa Highwall Miner          Alabama
# 1     2013   103404                Reid School Mine          Alabama
# 2     2013   100759  North River #1 Underground Min          Alabama
# 3     2013   103246                      Bear Creek          Alabama
# 4     2013   103451                     Knight Mine          Alabama
# ...    ...      ...                             ...              ...
# 1418  2013  4800677                Jim Bridger Mine          Wyoming
# 1419  2013  4801180   Black Butte And Leucite Hills          Wyoming
# 1420  2013  4801646   Bridger Underground Coal Mine          Wyoming
# 1428  2013  3603561                   Mcclure Strip  Refuse Recovery
# 1447  2013  4407233                        Gobco #8  Refuse Recovery
#
#      Mine County                         Mine Status    Mine Type  \
# 0           Bibb  Active, men working, not producing      Surface
# ...

# %%
#Q12.Write a Pandas program to import excel data  into a dataframe and find details where "Mine Name" starts with "P

df[df['Mine Name'].apply(lambda x:str(x).startswith('P'))].head(3)
# Out:
#     Year  MSHA ID                      Mine Name Mine State Mine County  \
# 13  2013   103332                  Powhatan Mine    Alabama   Jefferson
# 18  2013   102976  Piney Woods Preparation Plant    Alabama      Shelby
# 19  2013   102976  Piney Woods Preparation Plant    Alabama      Shelby
#
#    Mine Status    Mine Type                  Company Type     Operation Type  \
# 13      Active      Surface  Indepedent Producer Operator          Mine only
# 18      Active      Surface  Indepedent Producer Operator  Preparation Plant
# 19      Active  Underground  Indepedent Producer Operator  Preparation Plant
#
#           Operating Company                Operating Company Address  \
# 13           Rac Mining Llc             P.O. Box 354, Lynn, AL 35575
# 18  Jesse Creek Mining, Llc  1615 Kent Dairy Rd, Alabaster, AL 35007
# 19  Jesse Creek Mining, Llc  1615 Kent Dairy Rd, Alabaster, AL 35007
#
#    Union Code   Coal Supply Region  Production (short tons)  \
# ...

# %%
#Q25.Write Pandas program to import three datasheets from a given excel data  into a single dataframe and 
#export the result into new Excel file


df1=pd.read_excel("C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\employee.xlsx",header=0,sheet_name=0)

df2=pd.read_excel("C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\employee.xlsx",header=0,sheet_name=1)

df3=pd.read_excel("C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\employee.xlsx",header=0,sheet_name=2)

df = pd.concat([df1, df2, df3])
df.to_excel('C:\\Users\\Lenovo\\Documents\\Python Practice\\Practice_Pandas\\output.xlsx', index=True)
